# %%
from rembg import remove
from PIL import Image

# %%
def bg_remover(image_path, image_output_path):
    input = Image.open(image_path)
    output = remove(input)
    output.save(image_output_path)
    return output

# %%
bg_remover('jerome.jpg', 'output.png')
# Out:
# <PIL.Image.Image image mode=RGBA size=960x957>
